# %% [markdown]
# # Installing Libraries

# %%
# %%capture

# !pip install pycld2
# !pip install contractions
# !pip install spacy

# %% [markdown]
# # Importing Libraries

# %%
#Libraries for data and regex handling
import re
import numpy as np
import pandas as pd
import time
from google.colab import drive

#Libraries for text preprocessing
import contractions
from pycld2 import detect
import nltk;
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer,word_tokenize

#Library for warnings
import warnings
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-921d61959d7f> in <module>()
#       8 #Libraries for text preprocessing
#       9 import contractions
# ---> 10 from pycld2 import detect
#      11 import nltk;
#      12 from nltk.corpus import stopwords
#
# ModuleNotFoundError: No module named 'pycld2'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# # Functions

# %%
def remove_emoji(string):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

# %%
def clean_text(document):
  document = re.sub("'<.*?>'", "", document)
  document = remove_emoji(document)
  document = re.sub('[-!.,?:;_()*/\|<>^°#@=%"&]+', "", document)
  document = re.sub(r'([a-z])\1+', r'\1\1', document)
  return document

# %%
def lang_dect(text):
    isReliable, textBytesFound, details = detect(text)
    if isReliable and (details[0][0] == 'ENGLISH'):
        return "English"
    return "Other"

# %%
def parser(document):
  document = contractions.fix(document) #contractions expansion
  document = document.lower() #converting all words in lower case
  document = re.sub("\d+", "", document) #numbers removal
  document = re.sub("[£$€₽¥]+", "money", document)

  return document

# %%
def text_prep(document):
  tokens = word_tokenize(document, language="english") #tokenization
  filtered_tokens = [token for token in tokens if token not in stop_words] #stop words removal
  #reconstruct document
  document = ' '.join(filtered_tokens)
  return document

# %%
def parser_ema(document):
  document = contractions.fix(document) #contractions expansion
  document = re.sub("\d+", "", document) #numbers removal
  document = re.sub("[£$€₽¥]+", "money", document)

  return document

# %%
def clean_text_ale(document):
  document = contractions.fix(document) 
  document = re.sub("<br>", "", document)
  document = re.sub("[£$€₽¥]+", "money", document)
  document = remove_emoji(document)
  document = re.sub('[-_()*/\|<>^°#@=%"&]+', "", document)
  return document

# %% [markdown]
# # Text Preprocessing

# %%
# Supressing warnings
pd.options.mode.chained_assignment = None
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %%
# NLTK Stop words
nltk.download('stopwords')
stop_words = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
#mount the drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Text_Mining_Project_Amazon/Reviews.csv')
df.head()
# Out:
#    Id  ...                                               Text
# 0   1  ...  I have bought several of the Vitality canned d...
# 1   2  ...  Product arrived labeled as Jumbo Salted Peanut...
# 2   3  ...  This is a confection that has been around a fe...
# 3   4  ...  If you are looking for the secret ingredient i...
# 4   5  ...  Great taffy at a great price.  There was a wid...
#
# [5 rows x 10 columns]

# %%
print(df.shape)
# Out:
# (568454, 10)

# %%
subset = {"UserId", "Time", "Text"}
AmazonReviews = df.drop_duplicates(subset=subset, keep="first")

# %%
AmazonReviews.shape
# Out:
# (393892, 10)

# %%
AmazonReviews.isna().sum()
# Out:
# Id                         0
# ProductId                  0
# UserId                     0
# ProfileName               11
# HelpfulnessNumerator       0
# HelpfulnessDenominator     0
# Score                      0
# Time                       0
# Summary                    3
# Text                       0
# dtype: int64

# %%
start = time.time()
AmazonReviews['Text'] = AmazonReviews['Text'].apply(clean_text)
end = time.time()
print(end - start)
# Out:
# 40.842726707458496

# %%
start = time.time()
Text = AmazonReviews['Text'].to_list()
Language = []
for i in range(0, len(Text)):
    try:
        Language.append(lang_dect(Text[i]))
    except:
        Language.append(False)
        continue
AmazonReviews['Language'] = Language
end = time.time()
print(end - start)
# Out:
# 16.318511486053467

# %%
print(AmazonReviews['Language'].value_counts())
# Out:
# English    393735
# Other         149
# False           8
# Name: Language, dtype: int64

# %%
AmazonReviews = AmazonReviews[AmazonReviews['Language'] == "English"]
AmazonReviews_ema = AmazonReviews.copy()

# %%
start = time.time()
AmazonReviews['Text'] = AmazonReviews['Text'].apply(parser)
end = time.time()
print(end - start)
# Out:
# 51.48536157608032

# %%
nltk.download('stopwords')
nltk.download('punkt')
stop_words = set(stopwords.words('english'))
tokenizer = RegexpTokenizer(r'\w+')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
start = time.time()
Documents = AmazonReviews['Text'].apply(text_prep)
end = time.time()
print(end - start)
# Out:
# 134.93397974967957

# %%
AmazonFinal = pd.DataFrame({'Text':Documents,
                            'Summary': AmazonReviews['Summary'],  
                            'Score': AmazonReviews['Score'],
                            })

# %%
AmazonFinal
# Out:
#                                                      Text  ... Score
# 0       bought several vitality canned dog food produc...  ...     5
# 1       product arrived labeled jumbo salted peanutsth...  ...     1
# 2       confection around centuries light pillowy citr...  ...     4
# 3       looking secret ingredient robitussin believe f...  ...     2
# 4       great taffy great price wide assortment yummy ...  ...     5
# ...                                                   ...  ...   ...
# 568449  great sesame chickenthis good better resturant...  ...     5
# 568450  disappointed flavor chocolate notes especially...  ...     2
# 568451  stars small give one training session tried tr...  ...     5
# 568452  best treats training rewarding dog good groomi...  ...     5
# 568453  satisfied product advertised use cereal raw vi...  ...     5
#
# [393735 rows x 3 columns]

# %%
AmazonFinal.to_csv("/content/drive/MyDrive/Text_Mining_Project_Amazon/AmazonFinal_diandre.csv", index = False)

# %% [markdown]
# # Some changes for Emanuele's tasks

# %%
start = time.time()
AmazonReviews_ema['Text'] = AmazonReviews_ema['Text'].apply(parser_ema)
end = time.time()
print(end - start)
# Out:
# 22.71772003173828

# %%
start = time.time()
Documents_ema = AmazonReviews_ema['Text'].apply(text_prep)
end = time.time()
print(end - start)
# Out:
# 179.2514684200287

# %%
AmazonReviews.columns
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text',
#        'Language'],
#       dtype='object')

# %%
AmazonFinal_ema = pd.DataFrame({'Text':Documents_ema,
                            'Summary': AmazonReviews['Summary'],  
                            'Score': AmazonReviews['Score'],
                            'Time': AmazonReviews['Time'],
                            'HelpfulnessNumerator': AmazonReviews['HelpfulnessNumerator']
                            })

# %%
AmazonFinal_ema
# Out:
#                                                      Text  ... HelpfulnessNumerator
# 0       I bought several Vitality canned dog food prod...  ...                    1
# 1       Product arrived labeled Jumbo Salted Peanutsth...  ...                    0
# 2       This confection around centuries It light pill...  ...                    1
# 3       If looking secret ingredient Robitussin I beli...  ...                    3
# 4       Great taffy great price There wide assortment ...  ...                    0
# ...                                                   ...  ...                  ...
# 568449  Great sesame chickenthis good better resturant...  ...                    0
# 568450  I disappointed flavor The chocolate notes espe...  ...                    0
# 568451  These stars small give one training session I ...  ...                    2
# 568452  These BEST treats training rewarding dog good ...  ...                    1
# 568453  I satisfied product advertised I use cereal ra...  ...                    0
#
# [393735 rows x 5 columns]

# %%
AmazonFinal_ema.to_csv("/content/drive/MyDrive/Text_Mining_Project_Amazon/AmazonFinal_diandreperema.csv", index = False)
